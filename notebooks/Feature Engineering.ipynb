# %% [markdown]
# ## Imports

# %%
import pandas as pd
import nltk
import numpy as np

# %% [markdown]
# ## Some Function Definitions

# %%
def read_text(path):
    with open(path, 'r') as file:
        return file.read()

# %%
def write_text(path, text):
    with open(path, 'w') as file:
        file.write(text)

# %%
def get_dictionary_from_text(text):
    data = {'token':[], 'pos':[], 'BIO':[]}
    for line in text.split('\n'):
        if line == '':
            data['token'].append('')
            data['pos'].append('')
            data['BIO'].append('')
        else:
            tok, pos, chk =  line.split('\t')
            data['token'].append(tok)
            data['pos'].append(pos)
            data['BIO'].append(chk)
            
    return data

# %% [markdown]
# ## Loading Training Data

# %%
train_text = read_text('../WSJ_CHUNK_FILES/WSJ_02-21.pos-chunk')

# %%
train_dict = get_dictionary_from_text(train_text)

# %%
train_df = pd.DataFrame.from_dict(train_dict)

# %%
train_df.head()
# Out:
#   token  pos   BIO
# 0
# 1    In   IN     O
# 2    an   DT  B-NP
# 3  Oct.  NNP  I-NP
# 4    19   CD  I-NP

# %% [markdown]
# ## Testing Stemmer and Lemmatizer

# %% [markdown]
# ### Stemmer

# %%
from nltk.stem.porter import PorterStemmer

# %%
porter_stemmer = PorterStemmer()

# %%
porter_stemmer.stem('provision')
# Out:
# 'provis'

# %%
# %timeit train_df.token.sample(1000).apply(porter_stemmer.stem)
# Out:
# 116 ms ± 5.69 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ### Lemmatizer

# %%
from nltk.stem import WordNetLemmatizer

# %%
wordnet_lemmatizer = WordNetLemmatizer()

# %%
wordnet_lemmatizer.lemmatize('dogs')
# Out:
# 'dog'

# %%
train_df.shape
# Out:
# (1979761, 3)

# %%
# %timeit train_df.token.sample(1000).apply(wordnet_lemmatizer.lemmatize)
# Out:
# 110 ms ± 13.8 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## Create Features

# %% [markdown]
# - orig_token
# - pos
# - lemma
# - stem
# - prev_token
# - prev_pos
# - prev_lemma
# - prev_stem
# - prev_prev_token
# - prev_prev_pos
# - prev_prev_lemma
# - prev_prev_stem
# - next_token
# - next_pos
# - next_lemma
# - next_stem
# - next_next_token
# - next_next_pos
# - next_next_lemma
# - next_next_stem
# - BIO

# %%
features_df = train_df.iloc[:,:2]

# %%
features_df.shape
# Out:
# (1979761, 2)

# %%
features_df.head()
# Out:
#   token  pos
# 0
# 1    In   IN
# 2    an   DT
# 3  Oct.  NNP
# 4    19   CD

# %%
features_df['lemma'] = features_df.token.apply(wordnet_lemmatizer.lemmatize)

# %%
features_df['stem'] = features_df.token.apply(porter_stemmer.stem)

# %%
features_dfs_dfures_df.sample(100)
# Out:
#                token  pos        lemma      stem
# 1369880          the   DT          the       the
# 1919983           of   IN           of        of
# 330929             %   NN            %         %
# 1872342       Patent  NNP       Patent    patent
# 1807377       assets  NNS        asset     asset
# 1441269           --    :           --        --
# 1777161           on   IN           on        on
# 337566             ,    ,            ,         ,
# 1080379            .    .            .         .
# 1347682          the   DT          the       the
# 1651906     industry   NN     industry  industri
# 1175376          LIN  NNP          LIN       lin
# 794694         Sept.  NNP        Sept.     sept.
# 1834477            ;    :            ;         ;
# 48303         assume   VB       assume     assum
# 1465883            ,    ,            ,         ,
# 1425248        could   MD        could     could
# 1578114        cards  NNS         card      card
# 918869     countries  NNS      country   countri
# 711404          2.77   CD         2.77      2.77
# 262607            as   IN            a        as
# 155484        Topper  NNP       Topper    topper
# 835490             ,    ,            ,         ,
# 193671      European   JJ     European  european
# 745350    businesses  NNS     business      busi
# 1835813            %   NN            %         %
# 114664             a   DT            a         a
# 116700        United  NNP       United      unit
# 135227         rival   JJ        rival     rival
# 872882          male   JJ         male      male
# ...              ...  ...          ...       ...
# 1276065      markets  NNS       market    market
# 910911           Kay  NNP          Kay       kay
# 785129      Exchange  NNP     Exchange   exchang
# 1573904         been  VBN         been      been
# 1722559            $    $            $         $
# 252109   confronting  VBG  confronting  confront
# 160379         stock   NN        stock     stock
# 264521           the   DT          the       the
# 1823765      outlook   NN      outlook   outlook
# 1967131        early   JJ        early     earli
# 143459             ,    ,            ,         ,
# 648981             .    .            .         .
# 238405          some   DT         some      some
# 220577             .    .            .         .
# 1678837       likely   JJ       likely      like
# 332488           the   DT          the       the
# 250917             ,    ,            ,         ,
# 1609364         have  VBP         have      have
# 1723651         role   NN         role      role
# 1911497   Additional   JJ   Additional     addit
# 1206774
# 495061     typically   RB    typically     typic
# 1384201           ad   NN           ad        ad
# 1710017       custom   NN       custom    custom
# 98457          rates  NNS         rate      rate
# 1053192
# 1630035          the   DT          the       the
# 617375            in   IN           in        in
# 741949          over   RP         over      over
# 269086             a   DT            a         a
#
# [100 rows x 4 columns]

# %%
def get_shifted_column(col, pad=0):
    if pad > 0:
        col = np.concatenate([['']*pad,col[:-pad]])
    elif pad == 0:
        pass
    elif pad < 0:
        col = np.concatenate([col[-pad:],['']*(-pad)])
        
    return col

# %% [markdown]
# ### Add previous and next token features also

# %%
features_df.head(1)
# Out:
#   token pos lemma stem
# 0

# %%
features_df['prev_token'] = get_shifted_column(features_df.token.values, +1)
features_df['prev_pos'] = get_shifted_column(features_df.pos.values, +1)
features_df['prev_lemma'] = get_shifted_column(features_df.lemma.values, +1)
features_df['prev_stem'] = get_shifted_column(features_df.stem.values, +1)

# %%
features_df['prev_prev_token'] = get_shifted_column(features_df.token.values, +2)
features_df['prev_prev_pos'] = get_shifted_column(features_df.pos.values, +2)
features_df['prev_prev_lemma'] = get_shifted_column(features_df.lemma.values, +2)
features_df['prev_prev_stem'] = get_shifted_column(features_df.stem.values, +2)

# %%
features_df['next_token'] = get_shifted_column(features_df.token.values, -1)
features_df['next_pos'] = get_shifted_column(features_df.pos.values, -1)
features_df['next_lemma'] = get_shifted_column(features_df.lemma.values, -1)
features_df['next_stem'] = get_shifted_column(features_df.stem.values, -1)

# %%
features_df['next_next_token'] = get_shifted_column(features_df.token.values, -2)
features_df['next_next_pos'] = get_shifted_column(features_df.pos.values, -2)
features_df['next_next_lemma'] = get_shifted_column(features_df.lemma.values, -2)
features_df['next_next_stem'] = get_shifted_column(features_df.stem.values, -2)

# %%
features_df['BIO'] = train_df.BIO.values

# %%
features_df.head(3)
# Out:
#   token pos lemma stem prev_token prev_pos prev_lemma prev_stem  \
# 0
# 1    In  IN    In   In
# 2    an  DT    an   an         In       IN         In        In
#
#   prev_prev_token prev_prev_pos  ...  prev_prev_stem next_token next_pos  \
# 0                                ...                         In       IN
# 1                                ...                         an       DT
# 2                                ...                       Oct.      NNP
#
#   next_lemma next_stem next_next_token next_next_pos next_next_lemma  \
# 0         In        In              an            DT              an
# 1         an        an            Oct.           NNP            Oct.
# 2       Oct.      oct.              19            CD              19
#
#   next_next_stem   BIO
# 0             an
# 1           oct.     O
# 2             19  B-NP
#
# [3 rows x 21 columns]

# %%
features_df.loc[features_df['prev_token'] == '', :]
# Out:
#                token  pos        lemma        stem prev_token prev_pos  \
# 0
# 1                 In   IN           In          In
# 51               Ms.  NNP          Ms.         ms.
# 57       Rolls-Royce  NNP  Rolls-Royce  rolls-royc
# 78               The   DT          The         the
# 91            Howard  NNP       Howard      howard
# 121             BELL  NNP         BELL        bell
# 137              The   DT          The         the
# 147                A   DT            A           A
# 156             Bell  NNP         Bell        bell
# 174        Investors  NNS    Investors    investor
# 200                A   DT            A           A
# 234             They  PRP         They        they
# 272              The   DT          The         the
# 290             Many   JJ         Many        mani
# 339               ``   ``           ``          ``
# 384               ``   ``           ``          ``
# 398        Currently   RB    Currently     current
# 429              But   CC          But         but
# 448              The   DT          The         the
# 495        Investors  NNS    Investors    investor
# 531              The   DT          The         the
# 547              Not   RB          Not         not
# 557              The   DT          The         the
# 606             What   WP         What        what
# 657        According  VBG    According      accord
# 676              The   DT          The         the
# 687              The   DT          The         the
# 712              The   DT          The         the
# 732        Companies  NNS    Companies     compani
# ...              ...  ...          ...         ...        ...      ...
# 1979034          Ray  NNP          Ray         ray
# 1979057            I  PRP            I           I
# 1979067          But   CC          But         but
# 1979073           ``   ``           ``          ``
# 1979101           ``   ``           ``          ``
# 1979118          Mr.  NNP          Mr.         mr.
# 1979128         That   DT         That        that
# 1979159    Meanwhile   RB    Meanwhile    meanwhil
# 1979198    Officials  NNS    Officials      offici
# 1979233           At   IN           At          At
# 1979253          The   DT          The         the
# 1979270     Citibank  NNP     Citibank    citibank
# 1979297     Together   RB     Together      togeth
# 1979317          But   CC          But         but
# 1979339    Officials  NNS    Officials      offici
# 1979386          Nor   CC          Nor         nor
# 1979411          The   DT          The         the
# 1979430         Even   RB         Even        even
# 1979448          UAL  NNP          UAL         ual
# 1979470          Los  NNP          Los          lo
# 1979504           In   IN           In          In
# 1979535          The   DT          The         the
# 1979560        Union  NNP        Union       union
# 1979589          The   DT          The         the
# 1979604          But   CC          But         but
# 1979634          The   DT          The         the
# 1979659           If   IN           If          If
# 1979703         Also   RB         Also        also
# 1979742         That   DT         That        that
# 1979760
#
#         prev_lemma prev_stem prev_prev_token prev_prev_pos  ...   \
# 0                                                           ...
# 1                                                           ...
# 51                                         .             .  ...
# 57                                         .             .  ...
# 78                                         .             .  ...
# 91                                      U.S.           NNP  ...
# 121                                        .             .  ...
# 137                                        .             .  ...
# 147                                        .             .  ...
# 156                                        .             .  ...
# 174                                        .             .  ...
# 200                                        .             .  ...
# 234                                        .             .  ...
# 272                                        .             .  ...
# 290                                        .             .  ...
# 339                                        .             .  ...
# 384                                        .             .  ...
# 398                                       ''            ''  ...
# 429                                        .             .  ...
# 448                                        .             .  ...
# 495                                        .             .  ...
# 531                                        .             .  ...
# 547                                        .             .  ...
# 557                                        .             .  ...
# 606                                       ''            ''  ...
# 657                                        .             .  ...
# 676                                        .             .  ...
# 687                                        .             .  ...
# 712                                        .             .  ...
# 732                                        .             .  ...
# ...            ...       ...             ...           ...  ...
# 1979034                                    .             .  ...
# 1979057                                    .             .  ...
# 1979067                                   ''            ''  ...
# 1979073                                    .             .  ...
# 1979101                                    .             .  ...
# 1979118                                   ''            ''  ...
# 1979128                                    .             .  ...
# 1979159                                    .             .  ...
# 1979198                                    .             .  ...
# 1979233                                    .             .  ...
# 1979253                                    .             .  ...
# 1979270                                    .             .  ...
# 1979297                                    .             .  ...
# 1979317                                    .             .  ...
# 1979339                                    .             .  ...
# 1979386                                    .             .  ...
# 1979411                                    .             .  ...
# 1979430                                    .             .  ...
# 1979448                                    .             .  ...
# 1979470                                    .             .  ...
# 1979504                                    .             .  ...
# 1979535                                    .             .  ...
# 1979560                                    .             .  ...
# 1979589                                    .             .  ...
# 1979604                                    .             .  ...
# 1979634                                    .             .  ...
# 1979659                                    .             .  ...
# 1979703                                    .             .  ...
# 1979742                                    .             .  ...
# 1979760                                    .             .  ...
#
#         prev_prev_stem  next_token next_pos  next_lemma next_stem  \
# 0                               In       IN          In        In
# 1                               an       DT          an        an
# 51                   .        Haag      NNP        Haag      haag
# 57                   .       Motor      NNP       Motor     motor
# 78                   .      luxury       NN      luxury    luxuri
# 91                u.s.      Mosher      NNP      Mosher    mosher
# 121                  .  INDUSTRIES      NNP  INDUSTRIES  industri
# 137                  .         new       JJ         new       new
# 147                  .      record       NN      record    record
# 156                  .           ,        ,           ,         ,
# 174                  .         are      VBP         are       are
# 200                  .         SEC      NNP         SEC       sec
# 234                  .        make      VBP        make      make
# 272                  .    proposed      VBN    proposed    propos
# 290                  .          of       IN          of        of
# 339                  .         The       DT         The       the
# 384                  .  Apparently       RB  Apparently     appar
# 398                 ''           ,        ,           ,         ,
# 429                  .       about       IN       about     about
# 448                  .     changes      NNS      change     chang
# 495                  .           ,        ,           ,         ,
# 531                  .         SEC      NNP         SEC       sec
# 547                  .         all      PDT         all       all
# 557                  .   Committee      NNP   Committee  committe
# 606                 ''         the       DT         the       the
# 657                  .          to       TO          to        to
# 676                  .         SEC      NNP         SEC       sec
# 687                  .       rules      NNS        rule      rule
# 712                  .    proposed      VBN    proposed    propos
# 732                  .       would       MD       would     would
# ...                ...         ...      ...         ...       ...
# 1979034              .       Neidl      NNP       Neidl     neidl
# 1979057              .          'm      VBP          'm        'm
# 1979067             ''      others      NNS      others     other
# 1979073              .           I      PRP           I         I
# 1979101              .        What       WP        What      what
# 1979118             ''       Trump      NNP       Trump     trump
# 1979128              .  skepticism       NN  skepticism   skeptic
# 1979159              .           ,        ,           ,         ,
# 1979198              .    familiar       JJ    familiar  familiar
# 1979233              .           $        $           $         $
# 1979253              .       first       JJ       first     first
# 1979270              .         and       CC         and       and
# 1979297              .           ,        ,           ,         ,
# 1979317              .       other       JJ       other     other
# 1979339              .    familiar       JJ    familiar  familiar
# 1979386              .          is      VBZ          is        is
# 1979411              .       group       NN       group     group
# 1979430              .          if       IN          if        if
# 1979448              .          's      POS          's        's
# 1979470              .     Angeles      NNP     Angeles     angel
# 1979504              .    addition       NN    addition     addit
# 1979535              .       group       NN       group     group
# 1979560              .    Chairman      NNP    Chairman  chairman
# 1979589              .       pilot       NN       pilot     pilot
# 1979604              .          if       IN          if        if
# 1979634              .      pilots      NNS       pilot     pilot
# 1979659              .        they      PRP        they      they
# 1979703              .           ,        ,           ,         ,
# 1979742              .       could       MD       could     could
# 1979760              .
#
#         next_next_token next_next_pos next_next_lemma next_next_stem   BIO
# 0                    an            DT              an             an
# 1                  Oct.           NNP            Oct.           oct.     O
# 51                plays           VBZ            play           play  B-NP
# 57                 Cars          NNPS            Cars            car  B-NP
# 78                 auto            NN            auto           auto  B-NP
# 91                    ,             ,               ,              ,  B-NP
# 121                Inc.           NNP            Inc.           inc.  B-NP
# 137                rate            NN            rate           rate  B-NP
# 147                date            NN            date           date  B-NP
# 156               based           VBN           based           base  B-NP
# 174           appealing           VBG       appealing         appeal  B-NP
# 200            proposal            NN        proposal         propos  B-NP
# 234                 the            DT             the            the  B-NP
# 272             changes           NNS          change          chang  B-NP
# 290                 the            DT             the            the  B-NP
# 339                 SEC           NNP             SEC            sec     O
# 384                 the            DT             the            the     O
# 398                 the            DT             the            the     O
# 429                  25            CD              25             25     O
# 448                were           VBD            were           were  B-NP
# 495               money            NN           money          money  B-NP
# 531                will            MD            will           will  B-NP
# 547               those            DT           those          those  B-NP
# 557                  on            IN              on             on  B-NP
# 606           investors           NNS        investor       investor  B-NP
# 657                some            DT            some           some     O
# 676                  's           POS              's             's  B-NP
# 687                will            MD            will           will  B-NP
# 712               rules           NNS            rule           rule  B-NP
# 732                  be            VB              be             be  B-NP
# ...                 ...           ...             ...            ...   ...
# 1979034              of            IN              of             of  B-NP
# 1979057            sure            JJ            sure           sure  B-NP
# 1979067        remained           VBD        remained         remain     O
# 1979073             was           VBD              wa             wa     O
# 1979101        happened           VBD        happened         happen     O
# 1979118           never            RB           never          never  B-NP
# 1979128           would            MD           would          would  B-NP
# 1979159        Citicorp           NNP        Citicorp       citicorp     O
# 1979198            with            IN            with           with  B-NP
# 1979233             250            CD             250            250     O
# 1979253             UAL           NNP             UAL            ual  B-NP
# 1979270           Chase           NNP           Chase          chase  B-NP
# 1979297        Citicorp           NNP        Citicorp       citicorp     O
# 1979317           banks           NNS            bank           bank     O
# 1979339            with            IN            with           with  B-NP
# 1979386             the            DT             the            the     O
# 1979411              's           POS              's             's  B-NP
# 1979430             the            DT             the            the     O
# 1979448           board            NN           board          board  B-NP
# 1979470        investor            NN        investor       investor  B-NP
# 1979504               ,             ,               ,              ,     O
# 1979535              's           POS              's             's  B-NP
# 1979560             F.C           NNP             F.C            f.c  B-NP
# 1979589           union            NN           union          union  B-NP
# 1979604             the            DT             the            the     O
# 1979634           could            MD           could          could  B-NP
# 1979659            were           VBD            were           were     O
# 1979703         because            IN         because         becaus     O
# 1979742            cost            VB            cost           cost  B-NP
# 1979760
#
# [79705 rows x 21 columns]

# %%
features_df.tail(20)
# Out:
#              token  pos      lemma      stem prev_token prev_pos prev_lemma  \
# 1979741                                               .        .          .
# 1979742       That   DT       That      that
# 1979743      could   MD      could     could       That       DT       That
# 1979744       cost   VB       cost      cost      could       MD      could
# 1979745        him  PRP        him       him       cost       VB       cost
# 1979746        the   DT        the       the        him      PRP        him
# 1979747     chance   NN     chance     chanc        the       DT        the
# 1979748         to   TO         to        to     chance       NN     chance
# 1979749  influence   VB  influence  influenc         to       TO         to
# 1979750        the   DT        the       the  influence       VB  influence
# 1979751    outcome   NN    outcome    outcom        the       DT        the
# 1979752        and   CC        and       and    outcome       NN    outcome
# 1979753    perhaps   RB    perhaps    perhap        and       CC        and
# 1979754       join   VB       join      join    perhaps       RB    perhaps
# 1979755        the   DT        the       the       join       VB       join
# 1979756    winning  VBG    winning       win        the       DT        the
# 1979757     bidder   NN     bidder    bidder    winning      VBG    winning
# 1979758          .    .          .         .     bidder       NN     bidder
# 1979759                                               .        .          .
# 1979760
#
#         prev_stem prev_prev_token prev_prev_pos  ...  prev_prev_stem  \
# 1979741         .         bidders           NNS  ...          bidder
# 1979742                         .             .  ...               .
# 1979743      that                                ...
# 1979744     could            That            DT  ...            that
# 1979745      cost           could            MD  ...           could
# 1979746       him            cost            VB  ...            cost
# 1979747       the             him           PRP  ...             him
# 1979748     chanc             the            DT  ...             the
# 1979749        to          chance            NN  ...           chanc
# 1979750  influenc              to            TO  ...              to
# 1979751       the       influence            VB  ...        influenc
# 1979752    outcom             the            DT  ...             the
# 1979753       and         outcome            NN  ...          outcom
# 1979754    perhap             and            CC  ...             and
# 1979755      join         perhaps            RB  ...          perhap
# 1979756       the            join            VB  ...            join
# 1979757       win             the            DT  ...             the
# 1979758    bidder         winning           VBG  ...             win
# 1979759         .          bidder            NN  ...          bidder
# 1979760                         .             .  ...               .
#
#         next_token next_pos next_lemma next_stem next_next_token  \
# 1979741       That       DT       That      that           could
# 1979742      could       MD      could     could            cost
# 1979743       cost       VB       cost      cost             him
# 1979744        him      PRP        him       him             the
# 1979745        the       DT        the       the          chance
# 1979746     chance       NN     chance     chanc              to
# 1979747         to       TO         to        to       influence
# 1979748  influence       VB  influence  influenc             the
# 1979749        the       DT        the       the         outcome
# 1979750    outcome       NN    outcome    outcom             and
# 1979751        and       CC        and       and         perhaps
# 1979752    perhaps       RB    perhaps    perhap            join
# 1979753       join       VB       join      join             the
# 1979754        the       DT        the       the         winning
# 1979755    winning      VBG    winning       win          bidder
# 1979756     bidder       NN     bidder    bidder               .
# 1979757          .        .          .         .
# 1979758
# 1979759
# 1979760
#
#         next_next_pos next_next_lemma next_next_stem   BIO
# 1979741            MD           could          could
# 1979742            VB            cost           cost  B-NP
# 1979743           PRP             him            him     O
# 1979744            DT             the            the     O
# 1979745            NN          chance          chanc  B-NP
# 1979746            TO              to             to  B-NP
# 1979747            VB       influence       influenc  I-NP
# 1979748            DT             the            the     O
# 1979749            NN         outcome         outcom     O
# 1979750            CC             and            and  B-NP
# 1979751            RB         perhaps         perhap  I-NP
# 1979752            VB            join           join     O
# 1979753            DT             the            the     O
# 1979754           VBG         winning            win     O
# 1979755            NN          bidder         bidder  B-NP
# 1979756             .               .              .  I-NP
# 1979757                                               I-NP
# 1979758                                                  O
# 1979759
# 1979760
#
# [20 rows x 21 columns]

# %% [markdown]
# ## Save Generated Training Data

# %%
def save_df_as_text(df, path):
    df.to_csv(path, sep='\t', header=False, index=False)

# %%
save_df_as_text(features_df, '../WSJ_CHUNK_FILES/training.feature_1')

# %%
features_df.to_csv('../WSJ_CHUNK_FILES/training.feature.csv', sep='\t', header=False, index=False)
